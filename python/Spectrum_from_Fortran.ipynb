# %%
import os
import sys
from pathlib import Path
from glob import glob
from scipy.io import FortranFile
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
sfile = '../tests/Slm.data'
nl = 1024
Slm = np.fromfile(sfile).reshape([nl, nl]).T
Slm = Slm[1:, 1:]

# %%
Slm[0,:]
# Out:
# array([0.01486735, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %%
l=1
Slm[0, 0:l+1]
# Out:
# array([0.01486735, 0.        ])

# %%
Slm_avg = np.zeros(nl)
Slm_avg[0] = Slm[0,0]
for l in range(1, nl-1):
    Slm_avg[l] = Slm[l,0:l].mean()

# %%
plt.figure()
plt.plot(Slm_avg[0:512])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
