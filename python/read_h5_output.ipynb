# %%
import os
import h5py
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
fname = '../tests/vt000001.h5'
os.path.exists(fname)
# Out:
# True

# %%
with h5py.File(fname, "r") as f:
    print(f.keys())
    key_list = list(f.keys())
    print(key_list)
    # Get data into numpy arrays
    vt = f[key_list[0]][()]
    dim1 = f[key_list[1]][()]
    dim2 = f[key_list[2]][()]
#     print(data)
    print(dim1.shape)
    print(dim2.shape)
vt
# Out:
# <KeysViewHDF5 ['Data', 'dim1', 'dim2']>
# ['Data', 'dim1', 'dim2']
# (1024,)
# (513,)
# array([[-145.24654 , -145.61949 , -145.98601 , ..., -144.08955 ,
#         -144.48154 , -144.86722 ],
#        [ 144.96387 ,  145.33682 ,  145.70334 , ...,  143.8069  ,
#          144.19887 ,  144.58455 ],
#        [ 141.64223 ,  141.47427 ,  141.28944 , ...,  142.03601 ,
#          141.92393 ,  141.79239 ],
#        ...,
#        [  14.962892,   17.01207 ,   19.151894, ...,    9.38245 ,
#           11.146373,   13.006987],
#        [ 116.77422 ,  117.91311 ,  119.058876, ...,  113.39408 ,
#          114.51519 ,  115.64175 ],
#        [-117.000305, -118.13919 , -119.28496 , ..., -113.62016 ,
#         -114.74127 , -115.86783 ]], dtype=float32)

# %%
plt.figure(figsize=(10,6))
plt.imshow(vt, origin='lower', cmap='bwr',vmin=-200, vmax=200)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
